# %%
import sys
# sys.path.append("..")
from eval_metric.report_aisu_cls import (
    ReportPerformanceComputor, ReportPerformanceComputorConfig
)
import pandas as pd

# %%
config = ReportPerformanceComputorConfig()
config.gt_name = "report"
computor = ReportPerformanceComputor(config)

# %%
path_jsonl = "/yinghepool/mabingqi/ms-swift/output/HeadReport_tt79k_InternVL3.5-4B-lora/infer_results-checkpoint-7000.jsonl"

# %%
df_performance, df_gt, df_pred = computor.deal_one_with_path_jsonl(path_jsonl)
# Out:
# gt:  10%|▉         | 497/5000 [00:08<00:51, 86.86it/s] 2025-11-12 16:04:39.829 | WARNING  | eval_metric.report_aisu_cls:extract_aisu_from_report:107 - 1.3.46.670589.33.1.63783477834405538700001.4856574342152957205: extracted aisu [硬膜下出血] not in abnorm list
# gt:  19%|█▉        | 956/5000 [00:14<00:59, 68.40it/s] 2025-11-12 16:04:45.445 | WARNING  | eval_metric.report_aisu_cls:extract_aisu_from_report:107 - 1.3.46.670589.33.1.63788275300545493500002.5506404691982430779: extracted aisu [缺血性脑梗死] not in abnorm list
# gt:  32%|███▏      | 1618/5000 [00:21<00:34, 96.81it/s] 2025-11-12 16:04:52.407 | WARNING  | eval_metric.report_aisu_cls:extract_aisu_from_report:107 - 1.3.46.670589.33.1.63794390696480528100002.5027603664295400492: extracted aisu [硬膜下出血] not in abnorm list
# 2025-11-12 16:04:52.408 | WARNING  | eval_metric.report_aisu_cls:extract_aisu_from_report:107 - 1.2.840.113619.2.416.17135841580562433317960965631247257837: extracted aisu [硬膜下出血] not in abnorm list
# gt:  92%|█████████▏| 4579/5000 [00:57<00:04, 89.44it/s] 2025-11-12 16:05:29.062 | WARNING  | eval_metric.report_aisu_cls:extract_aisu_from_report:107 - 1.3.46.670589.33.1.63862788019987176200002.5129400986806268237: extracted aisu [脑积水] not in abnorm list
# gt: 100%|██████████| 5000/5000 [01:01<00:00, 81.04it/s]
# pred:  76%|███████▌  | 3785/5000 [00:33<00:09, 133.78it/s]2025-11-12 16:06:06.464 | WARNING  | eval_metric.report_aisu_cls:extract_aisu_from_report:107 - 1.3.46.670589.33.1.63853189638766917600002.5695602672847753722: extracted aisu [脑室内积血] not in abnorm list
# pred: 100%|██████████| 5000/5000 [00:42<00:00, 117.55it/s]

# %%
df_out = df_performance.copy()
df_diseases = df_out.iloc[:-2].sort_values(by="gt", ascending=False)
df_summary = df_out.iloc[-2:]
df_out = pd.concat([df_diseases, df_summary])
df_out
# Out:
#           name    gt    tp    fp    fn     tn  recall  precision      f1
# 6      缺血性白质病变  1829  1306   315   523   2856  0.7141     0.8057  0.7571
# 17          钙化  1788  1005   414   783   2798  0.5621     0.7082  0.6267
# 13         脑萎缩  1266   846   376   420   3358  0.6682     0.6923  0.6800
# 10         脑梗死   618   219   150   399   4232  0.3544     0.5935  0.4438
# 0           囊肿   512   179    76   333   4412  0.3496     0.7020  0.4668
# 14      腔隙性脑梗死   503   130   245   373   4252  0.2584     0.3467  0.2961
# 16         软化灶   363   153    90   210   4547  0.4215     0.6296  0.5049
# 8          脑出血   327   227    63   100   4610  0.6942     0.7828  0.7358
# 15     蛛网膜下腔出血   246   114    55   132   4699  0.4634     0.6746  0.5494
# 12         脑肿物   182    99   102    83   4716  0.5440     0.4925  0.5170
# 4        硬膜下血肿   182   108    44    74   4774  0.5934     0.7105  0.6467
# 9         脑挫裂伤   116    66    19    50   4865  0.5690     0.7765  0.6567
# 11          脑疝    98    51    59    47   4843  0.5204     0.4636  0.4904
# 1           水肿    91    18    16    73   4893  0.1978     0.5294  0.2880
# 3        硬膜下积液    69    12    17    57   4914  0.1739     0.4138  0.2449
# 2         破入脑室    54    17    37    37   4909  0.3148     0.3148  0.3148
# 5        硬膜外血肿    36    15    12    21   4952  0.4167     0.5556  0.4762
# 7          脂肪瘤    25     0     0    25   4975  0.0000     0.0000  0.0000
# 18         颅外疝     0     0     0     0   5000  0.0000     0.0000  0.0000
# 19  micro_mean  8305  4565  2090  3740  84605  0.5497     0.6860  0.6103
# 20  macro_mean     -     -     -     -      -  0.4114     0.5364  0.4576
